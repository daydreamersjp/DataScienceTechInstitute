# %% [markdown]
# # Data Retrieval from ebay API
# https://developer.ebay.com/devzone/finding/CallRef/index.html#CallIndex

# %% [markdown]
# ## Get Request to ebay API

# %%
from ebaysdk.finding import Connection

# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import re
import pickle

# %%
api = Connection(config_file='ebay.yaml', siteid="EBAY-US")

# %%
# %%time
outputs = []
for sio in [False, True]:
    output = []
    for i in range(5):
        request_complete = {
            'categoryId': '9355', # cellphone  
            'keywords': 'iphone',
            'itemFilter': [
                {'name': 'Currency', 'value': 'USD'},
                {'name': 'ListingType', 'value': 'FixedPrice'},
                {'name': 'EndTimeTo', 'value': '2019-10-26T00:00:00.000Z'}, #bids ending by October 26th. Month ends tend to have too many refurbished product.
                {'name': 'SoldItemsOnly', 'value': sio},
            ],
            'paginationInput': {
                    'entriesPerPage': 100,
                    'pageNumber': i+1
                },
            'HideDuplicateItems': True,
        }
        response_complete = api.execute('findCompletedItems', request_complete)
        print(f'SoldItemsOnly: {sio}, Page {i+1}: {len(response_complete.reply.searchResult.item)} results found.')
        output += response_complete.reply.searchResult.item
    outputs += [output]
# Out:
# SoldItemsOnly: False, Page 1: 100 results found.
# SoldItemsOnly: False, Page 2: 100 results found.
# SoldItemsOnly: False, Page 3: 100 results found.
# SoldItemsOnly: False, Page 4: 100 results found.
# SoldItemsOnly: False, Page 5: 100 results found.
# SoldItemsOnly: True, Page 1: 100 results found.
# SoldItemsOnly: True, Page 2: 100 results found.
# SoldItemsOnly: True, Page 3: 100 results found.
# SoldItemsOnly: True, Page 4: 100 results found.
# SoldItemsOnly: True, Page 5: 100 results found.
# Wall time: 17 s

# %%
pickle_out = open("outputfile_dict_test","wb")
pickle.dump(outputs, pickle_out)
pickle_out.close()

outputs
# Out:
# [[{'itemId': '283654427821', 'title': 'Apple iPhone 7 Plus - 128GB - Rose Gold (Verizon) A1661 (CDMA + GSM)', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs2.ebaystatic.com/m/mmvm7Vye9zoYQ9QKJ85CSwg/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-7-Plus-128GB-Rose-Gold-Verizon-A1661-CDMA-GSM-/283654427821', 'productId': {'_type': 'ReferenceID', 'value': '225203100'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '117**', 'location': 'Bellmore,NY,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '3'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '299.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '299.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'true', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 25, 23, 44, 8), 'endTime': datetime.datetime(2019, 10, 25, 23, 58, 49), 'listingType': 'FixedPrice', 'gift': 'false'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '163903189558', 'title': 'Apple iPhone 6  - 16GB - Space Gray A1549 Sprint no power', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs3.ebaystatic.com/m/mMFikm2s4w-2k7HTBWcRt2w/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-6-16GB-Space-Gray-A1549-Sprint-no-power-/163903189558', 'productId': {'_type': 'ReferenceID', 'value': '203743210'}, 'paymentMethod': 'PayPal', 'autoPay': 'false', 'postalCode': '466**', 'location': 'South Bend,IN,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '2'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '10.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '10.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 12, 14, 32, 22), 'endTime': datetime.datetime(2019, 10, 25, 23, 58, 40), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '8'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '7000', 'conditionDisplayName': 'For parts or not working'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '312786482427', 'title': 'iPhone 8 Plus | GSM Factory Unlocked | AT&T T-Mobile | 64GB 256GB | Excellent', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/pict/04040_0.jpg', 'viewItemURL': 'https://www.ebay.com/itm/iPhone-8-Plus-GSM-Factory-Unlocked-AT-T-T-Mobile-64GB-256GB-Excellent-/312786482427?var=0', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '900**', 'location': 'Los Angeles,CA,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '429.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '429.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 9, 29, 19, 54, 55), 'endTime': datetime.datetime(2019, 10, 25, 23, 58, 27), 'listingType': 'StoreInventory', 'gift': 'false', 'watchCount': '10'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '2500', 'conditionDisplayName': 'Seller refurbished'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'true'},
#   {'itemId': '312786482427', 'title': 'iPhone 8 Plus | GSM Factory Unlocked | AT&T T-Mobile | 64GB 256GB | Excellent', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs4.ebaystatic.com/pict/312786482427404000000002_1.jpg', 'viewItemURL': 'https://www.ebay.com/itm/iPhone-8-Plus-GSM-Factory-Unlocked-AT-T-T-Mobile-64GB-256GB-Excellent-/312786482427?var=611516050626', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '900**', 'location': 'Los Angeles,CA,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '488.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '488.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 9, 29, 19, 54, 55), 'endTime': datetime.datetime(2019, 10, 25, 23, 58, 27), 'listingType': 'StoreInventory', 'gift': 'false'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '2500', 'conditionDisplayName': 'Seller refurbished'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'true'},
#   {'itemId': '312786482427', 'title': 'iPhone 8 Plus | GSM Factory Unlocked | AT&T T-Mobile | 64GB 256GB | Excellent', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs4.ebaystatic.com/pict/312786482427404000000001_1.jpg', 'viewItemURL': 'https://www.ebay.com/itm/iPhone-8-Plus-GSM-Factory-Unlocked-AT-T-T-Mobile-64GB-256GB-Excellent-/312786482427?var=611516056147', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '900**', 'location': 'Los Angeles,CA,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '449.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '449.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 9, 29, 19, 54, 55), 'endTime': datetime.datetime(2019, 10, 25, 23, 58, 27), 'listingType': 'StoreInventory', 'gift': 'false'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '2500', 'conditionDisplayName': 'Seller refurbished'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'true'},
#   {'itemId': '143411451566', 'title': 'Apple iPhone 7 Plus - 128GB -Silver (Verizon) FACTORY UNLOCKED! Good Condition!', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs3.ebaystatic.com/m/mSTkSOTXXVMxXethWaxDOuA/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-7-Plus-128GB-Silver-Verizon-FACTORY-UNLOCKED-Good-Condition-/143411451566', 'productId': {'_type': 'ReferenceID', 'value': '225207916'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '201**', 'location': 'Ashburn,VA,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '329.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '329.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 14, 21, 4, 59), 'endTime': datetime.datetime(2019, 10, 25, 23, 57, 49), 'listingType': 'StoreInventory', 'gift': 'false', 'watchCount': '2'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '2000', 'conditionDisplayName': 'Manufacturer refurbished'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'true'},
#   {'itemId': '264498062063', 'title': 'Apple iPhone 5S - 16GB - Gray - Factory Unlocked; AT&T / T-Mobile / Global', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs4.ebaystatic.com/m/mcTLQPj3w87ab7kK1weUriQ/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-5S-16GB-Gray-Factory-Unlocked-AT-T-T-Mobile-Global-/264498062063', 'productId': {'_type': 'ReferenceID', 'value': '168508202'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '347**', 'location': 'USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '5.0'}, 'shippingType': 'FlatDomesticCalculatedInternational', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '60.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '60.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'true', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 14, 3, 35, 5), 'endTime': datetime.datetime(2019, 10, 25, 23, 56, 22), 'listingType': 'FixedPrice', 'gift': 'false'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '2500', 'conditionDisplayName': 'Seller refurbished'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '223719720014', 'title': 'Apple iPhone 8 - 256GB - Gold (Unlocked) A1863 (CDMA + GSM) GREAT CONDITION', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs3.ebaystatic.com/m/mPwd3ndrXhYSNeqHiVGizdA/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-8-256GB-Gold-Unlocked-A1863-CDMA-GSM-GREAT-CONDITION-/223719720014', 'productId': {'_type': 'ReferenceID', 'value': '240531018'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '296**', 'location': 'Greenville,SC,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '3'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '335.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '335.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 24, 23, 2, 50), 'endTime': datetime.datetime(2019, 10, 25, 23, 54, 26), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '5'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '273059730830', 'title': 'Apple iPhone 6 16GB, 64GB, 128GB Unlocked at&t tmobile Verizon LTE 4G Smartphone', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs3.ebaystatic.com/pict/2730597308304040_1.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-6-16GB-64GB-128GB-Unlocked-at-t-tmobile-Verizon-LTE-4G-Smartphone-/273059730830?var=572396736856', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '328**', 'location': 'Orlando,FL,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '9.99'}, 'shippingType': 'Flat', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '0'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '109.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '109.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2018, 2, 7, 17, 3, 45), 'endTime': datetime.datetime(2019, 10, 25, 23, 53, 7), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '32'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '2000', 'conditionDisplayName': 'Manufacturer refurbished'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'true'},
#   {'itemId': '401492404028', 'title': 'Apple iPhone 6S Plus 32GB Verizon Wireless 4G LTE 12MP Camera iOS Smartphone', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/pict/401492404028404000000003_1.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-6S-Plus-32GB-Verizon-Wireless-4G-LTE-12MP-Camera-iOS-Smartphone-/401492404028?var=671170789268', 'autoPay': 'true', 'postalCode': '070**', 'location': 'Clifton,NJ,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '179.95'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '179.95'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2018, 2, 12, 19, 37, 9), 'endTime': datetime.datetime(2019, 10, 25, 23, 51, 51), 'listingType': 'StoreInventory', 'gift': 'false', 'watchCount': '2'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '2500', 'conditionDisplayName': 'Seller refurbished'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'true'},
#   {'itemId': '283652327495', 'title': 'Apple iPhone XS - 256GB - Space Gray (Unlocked) (CDMA + GSM) - New Sealed', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs4.ebaystatic.com/m/m98HOWRcvogzQ81ggqJDONw/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-XS-256GB-Space-Gray-Unlocked-CDMA-GSM-New-Sealed-/283652327495', 'productId': {'_type': 'ReferenceID', 'value': '6023706166'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '926**', 'location': 'Westminster,CA,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '899.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '899.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 23, 18, 35, 40), 'endTime': datetime.datetime(2019, 10, 25, 23, 51, 48), 'listingType': 'StoreInventory', 'gift': 'false', 'watchCount': '4'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '1000', 'conditionDisplayName': 'New'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '202351039991', 'title': 'New Apple iPhone SE 16GB 32GB 64GB 128GB Factory Unlocked T-Mobile AT&T Verizon', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs4.ebaystatic.com/pict/202351039991404000000001_1.jpg', 'viewItemURL': 'https://www.ebay.com/itm/New-Apple-iPhone-SE-16GB-32GB-64GB-128GB-Factory-Unlocked-T-Mobile-AT-T-Verizon-/202351039991?var=502368222087', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '914**', 'location': 'USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'true', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '279.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '279.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2018, 6, 25, 23, 12, 15), 'endTime': datetime.datetime(2019, 10, 25, 23, 51, 19), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '4'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '1000', 'conditionDisplayName': 'New'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'true'},
#   {'itemId': '143130339725', 'title': 'NEW *BNIB*  T-MOBILE Apple iPhone 6 - 16/64/128GB Unlocked UNLOCKED Smartphone', 'globalId': 'EBAY-US', 'subtitle': 'NO-RUSH 14 DAYS SHIPPING ONLY!  US LOCATION!', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/pict/04040_0.jpg', 'viewItemURL': 'https://www.ebay.com/itm/NEW-BNIB-T-MOBILE-Apple-iPhone-6-16-64-128GB-Unlocked-UNLOCKED-Smartphone-/143130339725?var=0', 'paymentMethod': 'PayPal', 'autoPay': 'false', 'postalCode': '100**', 'location': 'New York,NY,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '3'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '167.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '167.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 2, 13, 14, 1), 'endTime': datetime.datetime(2019, 10, 25, 23, 50, 48), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '7'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '1000', 'conditionDisplayName': 'New'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'false'},
#   {'itemId': '143130339725', 'title': 'NEW *BNIB*  T-MOBILE Apple iPhone 6 - 16/64/128GB Unlocked UNLOCKED Smartphone', 'globalId': 'EBAY-US', 'subtitle': 'NO-RUSH 14 DAYS SHIPPING ONLY!  US LOCATION!', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs2.ebaystatic.com/pict/143130339725404000000001_1.jpg', 'viewItemURL': 'https://www.ebay.com/itm/NEW-BNIB-T-MOBILE-Apple-iPhone-6-16-64-128GB-Unlocked-UNLOCKED-Smartphone-/143130339725?var=442082029658', 'paymentMethod': 'PayPal', 'autoPay': 'false', 'postalCode': '100**', 'location': 'New York,NY,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '3'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '190.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '190.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 2, 13, 14, 1), 'endTime': datetime.datetime(2019, 10, 25, 23, 50, 48), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '2'}, 'returnsAccepted': 'true', 'galleryPlusPictureURL': 'https://galleryplus.ebayimg.com/ws/web/143130339725_1_48_1_00000001.jpg', 'condition': {'conditionId': '1000', 'conditionDisplayName': 'New'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'false'},
#   {'itemId': '123864570220', 'title': 'Apple iPhone 8 a1863 256GB Verizon Great Condition (Unlocked)', 'globalId': 'EBAY-US', 'subtitle': 'Certified Pre-Owned by Verizon - Free Shipping', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/pict/123864570220404000000001_1.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-8-a1863-256GB-Verizon-Great-Condition-Unlocked-/123864570220?var=424590129789', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'location': 'USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'true', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '399.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '399.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 8, 5, 9, 24, 33), 'endTime': datetime.datetime(2019, 10, 25, 23, 50, 36), 'listingType': 'StoreInventory', 'gift': 'false', 'watchCount': '40'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '2000', 'conditionDisplayName': 'Manufacturer refurbished'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'true'},
#   {'itemId': '273693296263', 'title': 'Apple iPhone 7 Plus (All Colors) 32GB 128GB 256GB - Unlocked / AT&T/  Sprint', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs4.ebaystatic.com/pict/273693296263404000000005_1.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-7-Plus-All-Colors-32GB-128GB-256GB-Unlocked-AT-T-Sprint-/273693296263?var=573222855439', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '328**', 'location': 'Orlando,FL,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '0'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '329.97'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '329.97'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 2, 8, 20, 56, 10), 'endTime': datetime.datetime(2019, 10, 25, 23, 50, 25), 'listingType': 'StoreInventory', 'gift': 'false', 'watchCount': '16'}, 'returnsAccepted': 'true', 'galleryPlusPictureURL': 'https://galleryplus.ebayimg.com/ws/web/273693296263_1_944_1_00000005.jpg', 'condition': {'conditionId': '2500', 'conditionDisplayName': 'Seller refurbished'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'true'},
#   {'itemId': '273905610597', 'title': 'Apple iPhone 7 32GB, 128GB, 256GB CDMA/GSM Unlocked Verizon AT&T T-Mobile Sprin', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs2.ebaystatic.com/pict/2739056105974040_1.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-7-32GB-128GB-256GB-CDMA-GSM-Unlocked-Verizon-AT-T-T-Mobile-Sprin-/273905610597?var=573757978719', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '328**', 'location': 'Orlando,FL,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '8.99'}, 'shippingType': 'Flat', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '0'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '131.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '131.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 6, 26, 12, 32, 47), 'endTime': datetime.datetime(2019, 10, 25, 23, 49, 12), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '3'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'true'},
#   {'itemId': '202801851981', 'title': 'Apple iPhone 7 a1660 128GB Verizon Unlocked-Excellent', 'globalId': 'EBAY-US', 'subtitle': '1M+ devices sold - 20yrs. Experience - OEM Accessories', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs2.ebaystatic.com/pict/202801851981404000000003_1.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-7-a1660-128GB-Verizon-Unlocked-Excellent-/202801851981?var=502958263677', 'autoPay': 'true', 'location': 'USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'true', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '239.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '239.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 17, 11, 23, 13), 'endTime': datetime.datetime(2019, 10, 25, 23, 49, 7), 'listingType': 'FixedPrice', 'gift': 'false'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '2000', 'conditionDisplayName': 'Manufacturer refurbished'}, 'isMultiVariationListing': 'true', 'discountPriceInfo': {'originalRetailPrice': {'_currencyId': 'USD', 'value': '549.0'}, 'pricingTreatment': 'STP', 'soldOnEbay': 'false', 'soldOffEbay': 'false'}, 'topRatedListing': 'true'},
#   {'itemId': '283575619448', 'title': 'Apple iPhone SE 16GB 32GB 64GB 128GB - Unlocked/ Verizon/ AT&T/ T-Mobile/ Sprint', 'globalId': 'EBAY-US', 'subtitle': '12-MONTH WARRANTY • HAND TESTED • FREE SHIPPING', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/pict/2835756194484040_1.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-SE-16GB-32GB-64GB-128GB-Unlocked-Verizon-AT-T-T-Mobile-Sprint-/283575619448?var=584816504366', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '327**', 'location': 'Sanford,FL,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '0'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '89.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '89.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 8, 9, 19, 8, 28), 'endTime': datetime.datetime(2019, 10, 25, 23, 48, 55), 'listingType': 'StoreInventory', 'gift': 'false', 'watchCount': '1'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'true'},
#   {'itemId': '184009063155', 'title': 'Apple iPhone X - 64GB - Space Gray (Unlocked) A1865 - Cracked Screen - Plz Read!', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs4.ebaystatic.com/m/mDYCcWKfbsU85p11fZ1DAgA/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-X-64GB-Space-Gray-Unlocked-A1865-Cracked-Screen-Plz-Read-/184009063155', 'productId': {'_type': 'ReferenceID', 'value': '240377072'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '546**', 'location': 'Sparta,WI,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '2'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '249.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '249.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 25, 21, 50, 39), 'endTime': datetime.datetime(2019, 10, 25, 23, 48, 24), 'listingType': 'FixedPrice', 'gift': 'false'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '7000', 'conditionDisplayName': 'For parts or not working'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '184009114016', 'title': 'Brand New Unopened Apple iPhone 11 - 64GB White (Unlocked)', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/m/mqJhT2Bs_FJ4XMZzpTj6nSQ/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Brand-New-Unopened-Apple-iPhone-11-64GB-White-Unlocked-/184009114016', 'productId': {'_type': 'ReferenceID', 'value': '10034217463'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '061**', 'location': 'West Hartford,CT,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '689.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '689.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 25, 23, 18, 40), 'endTime': datetime.datetime(2019, 10, 25, 23, 48, 18), 'listingType': 'FixedPrice', 'gift': 'false'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '1000', 'conditionDisplayName': 'New'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '143407969150', 'title': 'Apple iPhone 6S Plus 64GB Rose Gold Sprint Smartphone MKVY2LL/A', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs3.ebaystatic.com/m/mFujWGWdlbUm5VQ1TuLBw6w/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-6S-Plus-64GB-Rose-Gold-Sprint-Smartphone-MKVY2LL-A-/143407969150', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '153**', 'location': 'Washington,PA,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '145.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '145.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 14, 15, 0, 23), 'endTime': datetime.datetime(2019, 10, 25, 23, 47, 34), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '4'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '302566688720', 'title': 'Apple iPhone SE 16GB 32GB No Touch ID Verizon Unlocked AT&T T-Mobile Sprint 1', 'globalId': 'EBAY-US', 'subtitle': '30-Day Warranty - Free Charger & Cable - Easy Returns!', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/pict/3025666887204040_3.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-SE-16GB-32GB-No-Touch-ID-Verizon-Unlocked-AT-T-T-Mobile-Sprint-1-/302566688720?var=601406589319', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '660**', 'location': 'Lawrence,KS,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '0'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '80.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '80.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2017, 12, 15, 20, 1, 39), 'endTime': datetime.datetime(2019, 10, 25, 23, 47, 16), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '17'}, 'returnsAccepted': 'true', 'galleryPlusPictureURL': 'https://galleryplus.ebayimg.com/ws/web/302566688720_1_2323_1.jpg', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'true'},
#   {'itemId': '303333989848', 'title': 'Apple iPhone 5s - 16GB - Space Gray (Straight Talk) A1533 (CDMA + GSM)', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/m/mwpnfwhpsflBP0HiJTDurZw/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-5s-16GB-Space-Gray-Straight-Talk-A1533-CDMA-GSM-/303333989848', 'productId': {'_type': 'ReferenceID', 'value': '241987057'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '398**', 'location': 'Climax,GA,USA', 'country': 'US', 'shippingInfo': {'shippingType': 'Calculated', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '3'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '35.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '35.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'true', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 24, 13, 26, 41), 'endTime': datetime.datetime(2019, 10, 25, 23, 46, 21), 'listingType': 'FixedPrice', 'gift': 'false'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '143405010702', 'title': 'Good Condition Apple iPhone 5 - 64GB - Black & Slate (Factory Unlocked)', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs3.ebaystatic.com/m/mTuH-mP2vmfwcF7dpbwt1ag/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Good-Condition-Apple-iPhone-5-64GB-Black-Slate-Factory-Unlocked-/143405010702', 'productId': {'_type': 'ReferenceID', 'value': '141161767'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '727**', 'location': 'Fayetteville,AR,USA', 'country': 'US', 'shippingInfo': {'shippingType': 'Calculated', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'true', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '34.95'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '34.95'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 7, 16, 21, 55), 'endTime': datetime.datetime(2019, 10, 25, 23, 45, 14), 'listingType': 'StoreInventory', 'gift': 'false'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'true'},
#   {'itemId': '392500170892', 'title': 'Apple iPhone XR - 128GB (Unlocked) A1984 (CDMA + GSM) NEW WHITE ONLY AVAILABLE', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/m/mU67BxZlRBtnXleP75R1EYQ/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-XR-128GB-Unlocked-A1984-CDMA-GSM-NEW-WHITE-ONLY-AVAILABLE-/392500170892', 'productId': {'_type': 'ReferenceID', 'value': '3023715537'}, 'paymentMethod': 'PayPal', 'autoPay': 'false', 'postalCode': '856**', 'location': 'Douglas,AZ,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '3'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '535.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '535.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 25, 20, 7, 36), 'endTime': datetime.datetime(2019, 10, 25, 23, 42, 14), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '5'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '1000', 'conditionDisplayName': 'New'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '183974727061', 'title': 'Apple iPhone XS - 64GB - Silver ( AT&T Cricket H2O Net10) 7/10', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs2.ebaystatic.com/m/mPoC9-PVWv19GXacCrqQdgQ/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-XS-64GB-Silver-AT-T-Cricket-H2O-Net10-7-10-/183974727061', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '507**', 'location': 'Waterloo,IA,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'true', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '495.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '495.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 9, 28, 23, 48, 28), 'endTime': datetime.datetime(2019, 10, 25, 23, 41, 39), 'listingType': 'StoreInventory', 'gift': 'false', 'watchCount': '7'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'true'},
#   {'itemId': '264502270514', 'title': 'Apple iPhone 6s 16GB A1688 MKRT2LL/A iOS11.4.1 Unlocked GOOD TO GREAT 208798B', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs3.ebaystatic.com/m/mj2-17ME3u8UEds8dFTwX0w/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-6s-16GB-A1688-MKRT2LL-A-iOS11-4-1-Unlocked-GOOD-GREAT-208798B-/264502270514', 'productId': {'_type': 'ReferenceID', 'value': '216202239'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '971**', 'location': 'McMinnville,OR,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '0'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '107.2'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '107.2'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 17, 22, 19, 43), 'endTime': datetime.datetime(2019, 10, 25, 23, 40, 51), 'listingType': 'StoreInventory', 'gift': 'false'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '143398611906', 'title': 'Apple iPhone 5s - 16GB - Silver (T-Mobile) A1533 (GSM) Bad Touch IMEI? 36527', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs3.ebaystatic.com/m/mVrqIalMhQgA1O0OFUmGmCg/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-5s-16GB-Silver-T-Mobile-A1533-GSM-Bad-Touch-IMEI-36527-/143398611906', 'productId': {'_type': 'ReferenceID', 'value': '168576418'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '443**', 'location': 'Akron,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '0'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '22.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '22.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 9, 30, 16, 23, 5), 'endTime': datetime.datetime(2019, 10, 25, 23, 40, 33), 'listingType': 'StoreInventory', 'gift': 'false', 'watchCount': '1'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '7000', 'conditionDisplayName': 'For parts or not working'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'true'},
#   {'itemId': '323959310621', 'title': 'New Sealed - Apple iPhone 11 - 256GB - Black (Unlocked) A2111 (CDMA + GSM)', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs2.ebaystatic.com/m/mqssM0mbKOl1iH2EsXVUiCw/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/New-Sealed-Apple-iPhone-11-256GB-Black-Unlocked-A2111-CDMA-GSM-/323959310621', 'productId': {'_type': 'ReferenceID', 'value': '11034210179'}, 'paymentMethod': 'PayPal', 'autoPay': 'false', 'postalCode': '917**', 'location': 'California,CA,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '2'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '820.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '820.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'true', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 25, 22, 51, 23), 'endTime': datetime.datetime(2019, 10, 25, 23, 39, 30), 'listingType': 'FixedPrice', 'gift': 'false'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '1000', 'conditionDisplayName': 'New'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '163897827008', 'title': 'Apple iPhone XR 64GB GSM CDMA Fully Unlocked. Black Blue White Coral. Excellent', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/pict/163897827008404000000005_1.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-XR-64GB-GSM-CDMA-Fully-Unlocked-Black-Blue-White-Coral-Excellent-/163897827008?var=463496970532', 'autoPay': 'true', 'postalCode': '750**', 'location': 'Addison,TX,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '559.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '559.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 8, 18, 51, 11), 'endTime': datetime.datetime(2019, 10, 25, 23, 37, 58), 'listingType': 'StoreInventory', 'gift': 'false', 'watchCount': '1'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '2000', 'conditionDisplayName': 'Manufacturer refurbished'}, 'isMultiVariationListing': 'true', 'topRatedListing': 'true'},
#   {'itemId': '352830508938', 'title': 'Apple iPhone 5c - 16GB - White (Sprint) A1456 (CDMA + GSM)', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs3.ebaystatic.com/m/mnFbvcqFl_s4hGSSgTWT_eQ/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-5c-16GB-White-Sprint-A1456-CDMA-GSM-/352830508938', 'productId': {'_type': 'ReferenceID', 'value': '168576648'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '902**', 'location': 'Redondo Beach,CA,USA', 'country': 'US', 'shippingInfo': {'shippingType': 'Calculated', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '3'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '30.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '30.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'true', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 22, 17, 45, 19), 'endTime': datetime.datetime(2019, 10, 25, 23, 37, 31), 'listingType': 'FixedPrice', 'gift': 'false'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '163916338337', 'title': 'Apple iPhone 6s\xa0 (32GB) Space Gray (Unlocked) A1633 (CDMA + GSM)', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs2.ebaystatic.com/m/m5NXH9g6DCqGF93gbMyafWw/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-6s-32GB-Space-Gray-Unlocked-A1633-CDMA-GSM-/163916338337', 'productId': {'_type': 'ReferenceID', 'value': '228580046'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '453**', 'location': 'Ohio,OH,USA', 'country': 'US', 'shippingInfo': {'shippingType': 'Calculated', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '3'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '150.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '150.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 23, 17, 51, 36), 'endTime': datetime.datetime(2019, 10, 25, 23, 37, 15), 'listingType': 'FixedPrice', 'gift': 'false'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '1500', 'conditionDisplayName': 'Open box'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '293281637533', 'title': 'Apple iPhone 6s - 16GB - Space Gray (AT&T) A1633 (CDMA + GSM)', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs2.ebaystatic.com/m/mv28kyxHwwNSS0LX4hvBHJw/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-6s-16GB-Space-Gray-AT-T-A1633-CDMA-GSM-/293281637533', 'productId': {'_type': 'ReferenceID', 'value': '216227890'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '212**', 'location': 'Baltimore,MD,USA', 'country': 'US', 'shippingInfo': {'shippingType': 'Calculated', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '3'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '100.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '100.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'true', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 16, 13, 31, 48), 'endTime': datetime.datetime(2019, 10, 25, 23, 36, 12), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '2'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
# ...
#   {'itemId': '184004723235', 'title': 'Apple iPhone 11 - 64GB - Black (T-Mobile) A2111 (CDMA + GSM)', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs4.ebaystatic.com/m/mH4G0YDUwdj-rvjyk7XGaAw/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-11-64GB-Black-T-Mobile-A2111-CDMA-GSM-/184004723235', 'productId': {'_type': 'ReferenceID', 'value': '13034214301'}, 'paymentMethod': 'PayPal', 'autoPay': 'false', 'postalCode': '142**', 'location': 'Buffalo,NY,USA', 'country': 'US', 'shippingInfo': {'shippingType': 'Calculated', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '3'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '650.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '650.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'true', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 22, 15, 41, 45), 'endTime': datetime.datetime(2019, 10, 25, 17, 33, 45), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '14'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '1000', 'conditionDisplayName': 'New'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '372791747823', 'title': 'APPLE IPHONE 6S PLUS 6S+ UNLOCKED ROSE GOLD 128GB BRAND NEW', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs4.ebaystatic.com/m/mOyUgfewaX9ZwJ52jCGGsOg/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/APPLE-IPHONE-6S-PLUS-6S-UNLOCKED-ROSE-GOLD-128GB-BRAND-NEW-/372791747823', 'paymentMethod': 'PayPal', 'autoPay': 'false', 'postalCode': 'TS18***', 'location': 'United Kingdom', 'country': 'GB', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '1'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '367.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '367.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'true', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 2, 9, 45, 55), 'endTime': datetime.datetime(2019, 10, 25, 17, 33, 3), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '2'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '1500', 'conditionDisplayName': 'Open box'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '233380355511', 'title': 'Apple iPhone XR - 64GB - Product Red (T-Mobile) BAD ESN', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs4.ebaystatic.com/m/mJTjnOEMWGznSeXMLvryAlw/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-XR-64GB-Product-Red-T-Mobile-BAD-ESN-/233380355511', 'paymentMethod': 'PayPal', 'autoPay': 'false', 'postalCode': '065**', 'location': 'New Haven,CT,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '2'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '279.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '279.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 25, 16, 24, 31), 'endTime': datetime.datetime(2019, 10, 25, 17, 32, 57), 'listingType': 'StoreInventory', 'gift': 'false'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '7000', 'conditionDisplayName': 'For parts or not working'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '193176137864', 'title': 'Brand NEW Apple Iphone XS Max Factory Unlocked Space Grey 512GB', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/m/mNmo_n7847iZeCDpFJNAjGQ/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Brand-NEW-Apple-Iphone-XS-Max-Factory-Unlocked-Space-Grey-512GB-/193176137864', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '191**', 'location': 'Philadelphia,PA,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '5'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '730.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '730.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 25, 16, 47, 49), 'endTime': datetime.datetime(2019, 10, 25, 17, 32, 52), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '1'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '1000', 'conditionDisplayName': 'New'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '283654198729', 'title': 'Apple iPhone XS Max - 256GB - Space Gray (Verizon) A1921 (CDMA + GSM). Exce', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs2.ebaystatic.com/m/mrg8Z-WOXgyO9knITkPikBw/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-XS-Max-256GB-Space-Gray-Verizon-A1921-CDMA-GSM-Exce-/283654198729', 'productId': {'_type': 'ReferenceID', 'value': '16023701411'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '616**', 'location': 'Peoria,IL,USA', 'country': 'US', 'shippingInfo': {'shippingType': 'Calculated', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '2'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '600.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '600.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 25, 17, 31, 55), 'endTime': datetime.datetime(2019, 10, 25, 17, 32, 20), 'listingType': 'FixedPrice', 'gift': 'false'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '323955169545', 'title': 'Apple iPhone XR 128GB  BLUE (AT&T Only) - Great Condition READ DETAILS #20', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs2.ebaystatic.com/m/mL1bJMal2J0RwVHYD_WYGug/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-XR-128GB-BLUE-AT-T-Only-Great-Condition-READ-DETAILS-20-/323955169545', 'productId': {'_type': 'ReferenceID', 'value': '5023709629'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '799**', 'location': 'El Paso,TX,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '0'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '439.95'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '439.95'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 21, 18, 50, 50), 'endTime': datetime.datetime(2019, 10, 25, 17, 31, 4), 'listingType': 'StoreInventory', 'gift': 'false', 'watchCount': '6'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '312799275212', 'title': 'Apple iPhone 6 - 16GB - Space Gray A1549 For Parts/Not Working Read Description', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/m/mpnjqlJEccQuypXcgWKhVgQ/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-6-16GB-Space-Gray-A1549-Parts-Not-Working-Read-Description-/312799275212', 'productId': {'_type': 'ReferenceID', 'value': '241102259'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '852**', 'location': 'Tempe,AZ,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '0'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '22.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '22.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'true', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 10, 16, 43, 15), 'endTime': datetime.datetime(2019, 10, 25, 17, 30, 36), 'listingType': 'StoreInventory', 'gift': 'false', 'watchCount': '3'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '7000', 'conditionDisplayName': 'For parts or not working'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'true'},
#   {'itemId': '202807726308', 'title': 'Apple iPhone 8 Plus - 64GB - Space Gray (Unlocked) A1864 (CDMA   GSM)', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/m/mgfLDDhYIhXb79_obFnTJ7Q/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-8-Plus-64GB-Space-Gray-Unlocked-A1864-CDMA-GSM-/202807726308', 'productId': {'_type': 'ReferenceID', 'value': '240464787'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '183**', 'location': 'East Stroudsburg,PA,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'false', 'oneDayShippingAvailable': 'false', 'handlingTime': '3'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '372.5'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '372.5'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 25, 17, 21, 15), 'endTime': datetime.datetime(2019, 10, 25, 17, 30, 18), 'listingType': 'FixedPrice', 'gift': 'false'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '202805644404', 'title': 'Apple iPhone 7 Plus Rose Gold *iCloud* *Read Description*', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs1.ebaystatic.com/m/mHdqHEain9ty9Ug0Qpgd5oQ/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-7-Plus-Rose-Gold-iCloud-Read-Description-/202805644404', 'productId': {'_type': 'ReferenceID', 'value': '238463093'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '104**', 'location': 'Bronx,NY,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '3'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '119.99'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '119.99'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'true', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 22, 18, 29, 24), 'endTime': datetime.datetime(2019, 10, 25, 17, 29, 48), 'listingType': 'FixedPrice', 'gift': 'false', 'watchCount': '2'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '7000', 'conditionDisplayName': 'For parts or not working'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '274067556882', 'title': 'Apple iPhone 7 32GB - Rose Gold (SPRINT ONLY )', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs3.ebaystatic.com/m/mMZKxeJtGO7hPJewtqMI2Gw/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/Apple-iPhone-7-32GB-Rose-Gold-SPRINT-ONLY-/274067556882', 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '327**', 'location': 'Winter Park,FL,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '9.75'}, 'shippingType': 'Flat', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '0'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '175.0'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '175.0'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'true', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 10, 25, 14, 51, 41), 'endTime': datetime.datetime(2019, 10, 25, 17, 29, 48), 'listingType': 'FixedPrice', 'gift': 'false'}, 'returnsAccepted': 'false', 'condition': {'conditionId': '3000', 'conditionDisplayName': 'Used'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'false'},
#   {'itemId': '223615664071', 'title': 'SEALED  *READ* Apple iPhone XR BLACK  128GB Verizon A1984 (CDMA + GSM) #SA', 'globalId': 'EBAY-US', 'primaryCategory': {'categoryId': '9355', 'categoryName': 'Cell Phones & Smartphones'}, 'galleryURL': 'https://thumbs4.ebaystatic.com/m/mZyTtSjKD9JYn4_7SUmA3PQ/140.jpg', 'viewItemURL': 'https://www.ebay.com/itm/SEALED-READ-Apple-iPhone-XR-BLACK-128GB-Verizon-A1984-CDMA-GSM-SA-/223615664071', 'productId': {'_type': 'ReferenceID', 'value': '16023702391'}, 'paymentMethod': 'PayPal', 'autoPay': 'true', 'postalCode': '799**', 'location': 'El Paso,TX,USA', 'country': 'US', 'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD', 'value': '0.0'}, 'shippingType': 'Free', 'shipToLocations': 'Worldwide', 'expeditedShipping': 'true', 'oneDayShippingAvailable': 'false', 'handlingTime': '0'}, 'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '549.95'}, 'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '549.95'}, 'sellingState': 'Ended'}, 'listingInfo': {'bestOfferEnabled': 'false', 'buyItNowAvailable': 'false', 'startTime': datetime.datetime(2019, 8, 7, 21, 30, 25), 'endTime': datetime.datetime(2019, 10, 25, 17, 29, 12), 'listingType': 'StoreInventory', 'gift': 'false', 'watchCount': '12'}, 'returnsAccepted': 'true', 'condition': {'conditionId': '1000', 'conditionDisplayName': 'New'}, 'isMultiVariationListing': 'false', 'topRatedListing': 'true'}]]

# %%
# pickle_in = open("outputfile_dict_test","rb")
# outputs = pickle.load(pickle_in)

# %% [markdown]
# ## Putting data into pandas dataframe and preprocess

# %% [markdown]
# 1. Removal of records with duplicative ID (latest record remained)
# 2. Add a column for iPhone type
# 3. Add a column for iPhone disk size
# 4. Removal of records with None on iphoneType column or iphoneDiskSize column
# 5. Add a column for indicator of unlocked (sim free)
# 6. Add a column for duration by sales or cancel in days
# 7. Add a column for total price which is sum of price and shipping cost
# 8. Select necessary columns

# %%
#some record does not have shipping cost. Then, use $0.
def catch(func, *args, **kwargs):
    try:
        return func(*args, **kwargs)
    except Exception as e:
        return 0.0
    
def organize_output(o):
    outputs_organized = {
        'id': [oi.itemId for oi in o],
        'name': [oi.title for oi in o],
        'shippingcost': [catch(lambda: float(oi.shippingInfo.shippingServiceCost.value)) for oi in o],
        'price': [float(oi.sellingStatus.currentPrice.value) for oi in o],
        'starttime': [oi.listingInfo.startTime for oi in o],
        'endtime': [oi.listingInfo.endTime for oi in o],
        'condition': [oi.condition.conditionDisplayName for oi in o],
    }
    return outputs_organized

# %%
df_all, df_solditem = pd.DataFrame.from_dict( organize_output(outputs[0]) ), pd.DataFrame.from_dict( organize_output(outputs[1]) )

# Remove dups in id.
df_all.drop_duplicates(subset ="id", keep = 'first', inplace = True)
df_solditem.drop_duplicates(subset ="id", keep = 'first', inplace = True)
print(df_all.shape)

# Set sold flag
df_solditem = df_solditem[['id','endtime']]
df_final = df_all.join(df_solditem.set_index('id'), on='id', lsuffix='', rsuffix='_r')
df_final['sold'] = pd.isna(df_final['endtime_r'])
df_final['sold'] = 1 - df_final['sold']
df_final.drop(['endtime_r'],axis=1,inplace=True)

# Add iphone type column
def iphoneType(s):
    ls = s.lower().split()
    try:
        t1 = ls[ls.index('iphone')+1].replace(',','').replace('+','plus')
        p = ls[ls.index('iphone')+2].replace(',','')
        if p == 'plus' or p == '+': 
            t2 = 'plus'
        else: 
            t2 = ''
        return t1+t2
    except:
        return None
df_final['iphoneType'] = df_final['name'].map(iphoneType)

# Manual adjustment to iPhone type
conv = {
    '7plusplus': '7plus',
    '10s': 'xs',
    '7/7plus': '7',
    '8plusplus': '8plus',
    '5-': '5',
    '7-32gb': '7',
    '11-': '11',
    'eightplus': '8plus', 
    '6-16gb': '6',
    '7s': '7',
    'pro': '11',
    'blue': '11',
    '6se': '6s',
    'ten': 'x',
    'xs/max': 'xs',
    'se-t-mobile-space': 'se',
    '4-unlocked-verizon-sprint-8gb16gb32gb-mint': '4',
    'ten-r': 'xr',
    'xr-': 'xr',
    '6plusplus':'6plus',
}
def convType(t):
    if t in conv.keys():
        return conv[t]
    return t
df_final['iphoneType'] = df_final['iphoneType'].map(convType)

# Add iphone disk size column
def iphoneDiskSize(s):
    try:
        return int(re.search('\d+\s*gb',s.lower()).group()[:-2])
    except:
        return None
df_final['iphoneDiskSize'] = df_final['name'].map(iphoneDiskSize)
df_final = df_final[(df_final['iphoneDiskSize']!=2.0) & (df_final['iphoneDiskSize']!=18.0) & (df_final['iphoneDiskSize']!=6.0)]
print(df_final.shape)

# Remove records with None for iphoneType or iphoneDiskSize
df_final = df_final.dropna(subset=['iphoneType', 'iphoneDiskSize'])
print(df_final.shape)

# Add unlocked flag
def check_unlock(s):
    if ('unlock' in s.lower() or 'simfree' in s.lower() or 'sim free' in s.lower()):
        return 1
    return 0
df_final['unlocked'] = df_final.name.map(check_unlock)

# Duration by days
df_final['dur'] = df_final['endtime'] - df_final['starttime']
df_final['dur'] = df_final['dur'].map(lambda x: x.days + x.seconds/(24*60*60))
df_final = df_final.query('dur>0')
print(df_final.shape)

# Total price = price + shipping cost
df_final['tot_price'] = df_final['shippingcost'] + df_final['price']

# Final data
df_final = df_final[['condition','sold','iphoneType','iphoneDiskSize','unlocked','dur','tot_price']].reset_index(drop=True)

pickle_out = open("outputfile_df_final_test","wb")
pickle.dump(df_final, pickle_out)
pickle_out.close()

df_final.to_csv('outputfile_df_final_test.csv',index=False)

df_final
# Out:
# (461, 7)
# (458, 10)
# (427, 10)
# (427, 12)
#                     condition  sold iphoneType  iphoneDiskSize  unlocked  \
# 0                        Used     1      7plus           128.0         0
# 1    For parts or not working     1          6            16.0         0
# 2          Seller refurbished     1      8plus            64.0         1
# 3    Manufacturer refurbished     0      7plus           128.0         1
# 4          Seller refurbished     1         5s            16.0         1
# ..                        ...   ...        ...             ...       ...
# 422                  Open box     1         xr            64.0         0
# 423                      Used     1         6s            32.0         0
# 424        Seller refurbished     0      7plus            32.0         1
# 425  For parts or not working     1         6s            64.0         1
# 426                      Used     1         6s            32.0         0
#
#             dur  tot_price
# 0      0.010197     299.99
# 1     13.393264      10.00
# 2     26.169120     429.99
# 3     11.120023     329.99
# 4     11.848113      65.00
# ..          ...        ...
# 422    0.295475     400.00
# 423    0.004444     120.00
# 424  148.115150     298.99
# 425    0.715718      30.09
# 426    0.000567     100.00
#
# [427 rows x 7 columns]

# %% [markdown]
# ### A Quick EDA

# %%
col = df_final.columns
for i in range(5):
    print('*****************',col[i],'*****************\n',df_final[col[i]].value_counts(),'\n')
print('*****************',col[5],'*****************');plt.hist(df_final[col[-2]]);plt.show()
print('*****************',col[6],'*****************');plt.hist(df_final[col[-1]]);plt.show()
# Out:
# ***************** condition *****************
#  Used                        152
# Manufacturer refurbished    119
# Seller refurbished           52
# For parts or not working     38
# New                          35
# Open box                     31
# Name: condition, dtype: int64
#
# ***************** sold *****************
#  1    312
# 0    115
# Name: sold, dtype: int64
#
# ***************** iphoneType *****************
#  6s        54
# 7         49
# 7plus     39
# xr        30
# xs        29
# 6         27
# se        26
# x         25
# 6splus    24
# 8         24
# 8plus     24
# 6plus     19
# 5s        18
# 11        17
# 5          8
# 5c         5
# 4s         4
# 3gs        2
# 4          2
# 3g         1
# Name: iphoneType, dtype: int64
#
# ***************** iphoneDiskSize *****************
#  64.0     127
# 32.0      91
# 16.0      84
# 128.0     59
# 256.0     54
# 8.0        7
# 512.0      5
# Name: iphoneDiskSize, dtype: int64
#
# ***************** unlocked *****************
#  1    280
# 0    147
# Name: unlocked, dtype: int64
#
# ***************** dur *****************
# ***************** tot_price *****************

# %%
plt.hist(df_final[col[-2]][df_final[col[-2]]<=100],bins=100);plt.show()
